# %% [markdown]
# # Linear algebra with Numpy 🧠🧠
#
# Some practice exercises are available the [Linear Algebra prepwork](https://app.jedha.co/course/linear-algebra-basics/linear-algebra-exercises).
# In this exercise, you will apply what you learnt in the "Numpy and Linear Algebra" to check numerically the answers to these exercises.

# %%
import numpy as np

# %% [markdown]
# ## Operations with vectors and matrices 🤹‍♂️🤹‍♂️
#
# ### Vector operations
#
# 1. Compute the sum $\vec{u} + \vec{v}$ of the following vectors :
# $$
# \vec{u} =
# \begin{bmatrix}
# 2 \\
# 9 \\
# -1
# \end{bmatrix}
# $$
# $$
# \vec{v} =
# \begin{bmatrix}
# 1 \\
# 5 \\
# 3
# \end{bmatrix}
# $$

# %%
u = np.array([2, 9, -1])
v = np.array([1, 5, 3])

u + v
# Out:
# array([ 3, 14,  2])

# %% [markdown]
# 2. Compute the difference $\vec{u} - \vec{v}$ between the following vectors :
# $$
# \vec{u} =
# \begin{bmatrix}
# 10 \\
# -2 \\
# 1
# \end{bmatrix}
# $$
# $$
# \vec{v} =
# \begin{bmatrix}
# 4 \\
# 3 \\
# 2
# \end{bmatrix}
# $$

# %%
u = np.array([10, -2, 1])
v = np.array([4, 3, 2])

u - v
# Out:
# array([ 6, -5, -1])

# %% [markdown]
# 3. Compute : $\alpha (\vec{u} + \vec{v})$ with $\alpha = 4$ and :
# $$
# \vec{u} =
# \begin{bmatrix}
# 1 \\
# -2 \\
# 2
# \end{bmatrix}
# $$
# $$
# \vec{v} =
# \begin{bmatrix}
# 2 \\
# 1 \\
# 0
# \end{bmatrix}
# $$

# %%
alpha = 4
u = np.array([1, -2, 2])
v = np.array([2, 1, 0])

alpha*(u + v)
# Out:
# array([12, -4,  8])

# %% [markdown]
# 4. Compute the norms $\Vert\vec{u}\Vert$ and $\Vert\vec{v}\Vert$ with:
# $$
# \vec{u}
# =
# \begin{bmatrix}
# 1 \\
# 2 \\
# 3 \\
# 4 \\
# \end{bmatrix}
# $$
# $$
# \vec{v}
# =
# \begin{bmatrix}
# -1 \\
# 2 \\
# -3 \\
# 4 \\
# \end{bmatrix}
# $$

# %%
u = np.array([1, 2, 3, 4])
v = np.array([-1, 2, -3, 4])

print("Norm u: ", np.linalg.norm(u))
print("Norm v: ", np.linalg.norm(v))
# Out:
# Norm u:  5.477225575051661
# Norm v:  5.477225575051661

# %% [markdown]
# ### Matrix operations

# %% [markdown]
# 5. Compute the sum $A + B$ of the two following matrices :
# $$
# A =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 1 & 4 \\
# 3 & 4 & 1
# \end{bmatrix}
# $$
# $$
# B =
# \begin{bmatrix}
# 2 & 3 & 4 \\
# 3 & 2 & 5 \\
# 4 & 5 & 2
# \end{bmatrix}
# $$

# %%
A = np.array([[1, 2, 3],
              [2, 1, 4],
              [3, 4, 1]])

B = np.array([[2, 3, 4],
              [3, 2, 5],
              [4, 5, 2]])

A + B
# Out:
# array([[3, 5, 7],
#        [5, 3, 9],
#        [7, 9, 3]])

# %% [markdown]
# 6. Compute the operation $2A - B$ with:
# $$
# A =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 1 & 4 \\
# 3 & 4 & 1
# \end{bmatrix}
# $$
# $$
# B =
# \begin{bmatrix}
# 2 & 3 & 4 \\
# 3 & 2 & 5 \\
# 4 & 5 & 2
# \end{bmatrix}
# $$

# %%
2*A - B
# Out:
# array([[0, 1, 2],
#        [1, 0, 3],
#        [2, 3, 0]])

# %% [markdown]
# 7. Compute the products of matrices : $AB$ and $BA$ with:
# $$
# A =
# \begin{bmatrix}
# 1 & 0 & 2 \\
# 2 & 1 & 0 \\
# 1 & 2 & 1
# \end{bmatrix}
# $$
# $$
# B =
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 1 & 2 & 0 \\
# 0 & 1 & 2
# \end{bmatrix}
# $$

# %%
A = np.array([[1, 0, 2],
              [2, 1, 0],
              [1, 2, 1]])

B = np.array([[2, 0, 0],
              [1, 2, 0],
              [0, 1, 2]])

print('AB:')
print(A @ B)
print()
print('BA:')
print(B @ A)
# Out:
# AB:
# [[2 2 4]
#  [5 2 0]
#  [4 5 2]]
#
# BA:
# [[2 0 4]
#  [5 2 2]
#  [4 5 2]]

# %% [markdown]
# 8. Compute the products of matrices : $AB$ and $BA$ with:
# $$
# A =
# \begin{bmatrix}
# 1 & 0 \\
# 2 & 1 \\
# 1 & 2
# \end{bmatrix}
# $$
# $$
# B =
# \begin{bmatrix}
# 2 & 0 & 0 \\
# 1 & 2 & 0
# \end{bmatrix}
# $$

# %%
A = np.array([[1, 0],
              [2, 1],
              [1, 2]])

B = np.array([[2, 0, 0],
              [1, 2, 0]])

print('AB:')
print(A @ B)
print()
print('BA:')
print(B @ A)
# Out:
# AB:
# [[2 0 0]
#  [5 2 0]
#  [4 4 0]]
#
# BA:
# [[2 0]
#  [5 2]]

# %% [markdown]
# ### Matrix-vector product

# %% [markdown]
# 9. Compute the matrix-vector product $A\vec{v}$ with :
# $$
# A =
# \begin{bmatrix}
# 1 & 0 & 2 \\
# 2 & 1 & 0 \\
# 1 & 2 & 1
# \end{bmatrix}
# $$
# $$
# \vec{v} =
# \begin{bmatrix}
# -1 \\
# 1 \\
# 2
# \end{bmatrix}
# $$

# %%
A = np.array([[1, 0, 2],
              [2, 1, 0],
              [1, 2, 1]])

v = np.array([-1, 1, 2])

print(A @ v)
# Out:
# [ 3 -1  3]

# %% [markdown]
# ## Collinearity and orthogonality 🏌️🏌️

# %% [markdown]
# 10. Compute the dot product $\vec{u} \cdot \vec{v} $ with:
# $$
# \vec{u}
# =
# \begin{bmatrix}
# 2 \\
# -3 \\
# -1 \\
# \end{bmatrix}
# $$
# $$
# \vec{v}
# =
# \begin{bmatrix}
# 3 \\
# 1 \\
# 3 \\
# \end{bmatrix}
# $$
#
# What can you conclude about the angle between the two vectors ?

# %%
u = np.array([2, -3, -1])
v = np.array([3, 1, 3])

print("dot product: ", u.dot(v))
# Out:
# dot product:  0

# %% [markdown]
# The dot product is equal to zero, which means that $\vec u$ and $\vec v$ are orthogonal. The angle between the two vectors is 90°.

# %% [markdown]
# 11. Are $\vec{u}$, $\vec{v}$ collinear ?
# $$
# \vec{u}
# =
# \begin{bmatrix}
# 4 \\
# 2 \\
# -1
# \end{bmatrix}
# $$
#
# $$
# \vec{v}
# =
# \begin{bmatrix}
# -1 \\
# -\frac{1}{2} \\
# \frac{1}{4}
# \end{bmatrix}
# $$

# %%
u = np.array([4, 2, -1])
v = np.array([-1, -1/2, 1/4])

print("Element-wise division: ", u/v)
# Out:
# Element-wise division:  [-4. -4. -4.]

# %% [markdown]
# We just showed that $\vec u = -4\vec v$ which means that the vectors are colinear.

# %% [markdown]
# 12. Are $\vec{u}$, $\vec{v}$ and $\vec{w}$ linearly independent (i.e. there's no relationship of multicolinearity between these vectors) ?
# $$
# \vec{u}
# =
# \begin{bmatrix}
# 1 \\
# 2
# \end{bmatrix}
# $$
#
# $$
# \vec{v}
# =
# \begin{bmatrix}
# -2 \\
# 1 \\
# \end{bmatrix}
# $$
#
# $$
# \vec{w}
# =
# \begin{bmatrix}
# -1 \\
# 3
# \end{bmatrix}
# $$

# %%
u = np.array([1, 2])
v = np.array([-2, 1])
w = np.array([-1, 3])

print('u: ', u)
print('w - v:', w - v)
# Out:
# u:  [1 2]
# w - v: [1 2]

# %% [markdown]
# We just showed that $\vec u = \vec w - \vec v$ which means the vectors are not linearly independent !

# %% [markdown]
# ## Systems of linear equations 🧩🧩
#
# Consider the following system of linear equations :
#
# $$
# \begin{equation}
#     \begin{cases}
#       2x_1 + x_2 = 2\\
#       x_1 + 2x_2 + x_3 = 0 \\
#       x_2 + 2x_3 = 1
#     \end{cases}
# \end{equation}
# $$

# %% [markdown]
# 13. We'd like to write the matrix representation of this system of equations, in the form $A\vec{x} = \vec{c}$ where :
# - $A$ is a matrix containing the coefficients of the equation
# - $\vec{x}$ is the vector of unknowns
# - $\vec{c}$ is a vector of constant values
#
# Create a numpy array corresponding to $A$ and another corresponding to $\vec c$

# %%
A = np.array([[2, 1, 0],
              [1, 2, 1],
              [0, 1, 2]])

c = np.array([2, 0,1])

# %% [markdown]
# 14. Use numpy to solve the system of equations

# %%
x = np.linalg.solve(A, c)
print("Solution: x = ", x)
# Out:
# Solution: x =  [ 1.75 -1.5   1.25]

# %% [markdown]
# 15. **[Bonus question - for experts only 💪]** Let's use the concept of matrix inverse to solve the system of linear equations !
#
# * Prove that the following matrix is the inverse of matrix $A$ :
# $$
# B = \begin{bmatrix}
# \frac{3}{4} & - \frac{1}{2} & \frac{1}{4} \\
# -\frac{1}{2} & 1 & -\frac{1}{2} \\
# \frac{1}{4} & -\frac{1}{2} & \frac{3}{4}
# \end{bmatrix}
# $$
#
# * And then, use $B = A^{-1}$ to find the solution to the system of equation

# %%
A_inv = np.linalg.inv(A)
print("Inverse of A: ")
print(A_inv)
print()

print("Solution: x = ", A_inv @ c)
# Out:
# Inverse of A:
# [[ 0.75 -0.5   0.25]
#  [-0.5   1.   -0.5 ]
#  [ 0.25 -0.5   0.75]]
#
# Solution: x =  [ 1.75 -1.5   1.25]

# %% [markdown]
# ## Matrix diagonalization 🤸🤸

# %% [markdown]
# 15. Consider the following matrix :
#
# $$
# A =
# \begin{bmatrix}
# 3 & -1 \\
# 2 & 0
# \end{bmatrix}
# $$
#
# a. Show that $\vec{u} = \begin{bmatrix}1\\1\end{bmatrix}$ and $\vec{v} = \begin{bmatrix}1\\2\end{bmatrix}$ are eigenvectors of $A$
#
# b. What are the eigenvalues associated to $\vec{u}$ and $\vec{v}$ ?

# %%
# Method 1 - compute Au and Av

A = np.array([[3, -1],
              [2, 0]])

u = np.array([1, 1])
v = np.array([1, 2])

print("Au: ", A @ u)
print("Av: ", A @ v)
# Out:
# Au:  [2 2]
# Av:  [1 2]

# %% [markdown]
# We can notice that:
# * $A \vec u = 2 \vec u$ which means that $\vec u$ is an eigenvector of $A$ with eigenvalue 2
# * $A \vec v = \vec v$ which means that $\vec u$ is an eigenvector of $A$ with eigenvalue 1.

# %%
# Method 2 - with np.linalg.eig
eigenvals, eigenvecs = np.linalg.eig(A)
print("eigenvectors of A:")
print(eigenvecs)
print("eigenvalues of A:")
print(eigenvals)
# Out:
# eigenvectors of A:
# [[0.70710678 0.4472136 ]
#  [0.70710678 0.89442719]]
# eigenvalues of A:
# [2. 1.]

# %% [markdown]
# 💡With this second method, we find the same eigenvalues but not the same components for the eigenvectors. This is because `np.linalg.eig` finds normalized eigenvectors (= the norm is equal to 1). Our vectors $\vec u$ and $\vec v$ are actually colinear to the eigenvectors found by `np.linalg.eig`:
# * $0.707 \vec u = \begin{bmatrix}0.707 \\0.707 \end{bmatrix} $
# * $0.447 \vec v = \begin{bmatrix}0.447 \\0.894 \end{bmatrix}$
