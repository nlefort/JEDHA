# %% [markdown]
# # Connect the dots
#
# Now that you have a nice infrastructure built up, it's time to connect the dots with what you've learned with Tableau. Indeed, what we usually want in companies is to built automatic dashboard that connects directly to a Data Warehouse. Let's how we can do it. 🤸‍♀️
#
# ## What you will learn in this course 🧐🧐
#
# - Connect Tableau to Big Query using Google Sheets

# %% [markdown]
# ## Tableau & Big Query 💒
#
# Now that you know how to extract data using SQL, you can analyze it using Tableau. Here is a free way to do it:
#
# ![crack](https://essentials-assets.s3.eu-west-3.amazonaws.com/M02-SQL/Introduction_to_SQL_and_cloud_computing/tableau_to_bigquery_final.gif)

# %% [markdown]
# Here we connected Tableau to Google Spreadsheet, however there are a lot more connectors you can use. For example, if you were paying for the paid version of Tableau, you would be able to directly connect it to Big Query!

# %% [markdown]
# ## Resources 📚📚
#
# - Google Sheets - [https://bit.ly/32CSAs](https://www.google.com/sheets/about/)
# - Tableau Connectors - [https://bit.ly/CKsac](https://help.tableau.com/current/pro/desktop/en-us/exampleconnections_overview.htm)
