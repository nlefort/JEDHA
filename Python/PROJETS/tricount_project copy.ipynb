# %%
#tant que nous n'avons pas autant d'amis que de montants on continu la boucle

friends=input("what are the names of your friends (separate their names by a comma")
amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")

list_of_friends=friends.split(",")
list_of_amounts=amounts.split(",")

#tant que longueur liste amis est différente de liste montants édit "tu n'as pas entré le même nombre d'amis que de montant dépensé"

while len(list_of_friends) != len(list_of_amounts):
    print("you did not enter the same number of friends than amounts spent!")
# et donc tu recommences ta boucle...
    friends=input("what are the names of your friends (separate their names by a comma)")
    amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")

#tu sépares ta liste d'amis par une virgule, idem liste montants
    list_of_friends=friends.split(",")
    list_of_amounts=amounts.split(",")

else:
    friends=[]
    total_spent=0
    for friend, amount, in zip(list_of_friends, list_of_amounts):
        friends.append((friend, amount))
        total_spent+=int(amount)
print(friends)
print('total amount spent during the trips is:{}'.format(total_spent))
# Out:
# [('paul', '30'), (' jacques', '40'), (' jean', '60')]
# total amount spent during the trips is:130

# %%
#vérifier que les montants sont au bon formats

friends=input("what are the names of your friends (separate their names by a comma")
amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")

list_of_friends=friends.split(",")
list_of_amounts=amounts.split(",")

#en faisant juste le try, vu que j'ai une erreur sur le format de mon nombre, la nouvle continue de s'éxécuter sur le reste et je n'ai donc plus le même nombre de prénom et de montant

while True :
    try:
        list_of_amounts=[float(amount)for amount in list_of_amounts]
        break
    except:
        print('please enter numbers of the amounts spent')
        amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")
        list_of_amounts=amounts.split(",")

while len(list_of_friends) != len(list_of_amounts):
    print("you did not enter the same number of friends than amounts spent!")

    friends=input("what are the names of your friends (separate their names by a comma)")
    amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")

    list_of_friends=friends.split(",")
    list_of_amounts=amounts.split(",")

    while True :
        try:
            for i, amount in enumerate(list_of_amounts):
                list_of_amounts[i]=float(amount)
            break
        except:
            print('please enter numbers of the amounts spent')
            amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")
            list_of_amounts=amounts.split(",")

else:
    friends=[(friend, amount) for friend, amount in zip(list_of_friends,list_of_amounts)]
    total_spent=sum([amount for _, amount in friends])

#je fais mon calcule

    for friend, amount in zip(list_of_friends, list_of_amounts):
        even_share=total_spent/len(friends)
        friend_balance=float(amount)-even_share

        if friend_balance<0:
            print("{} needs to give {:.2f}".format(friend,-friend_balance))
        elif friend_balance>0:
            print("{} needs to receive {:.2f}".format(friend, friend_balance))
        else:
            print("{} doesn't need to receive anything".format(friend))
# Out:
# julia needs to give 10.00
#  antoie doesn't need to receive anything
#  lili needs to receive 10.00

# %%
#identifier les for loops
