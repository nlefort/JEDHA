# %% [markdown]
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8e in position 195982 : invalid start byte

# %%
df = pd.read_csv('name.csv', encoding = 'utf-8')

# %%
# Hmm il faut essayer d'autres choses alors, tu peux essayer 
encoding='ISO-8859-1' 

# ou alors tu peux essayer de determiner l'encoding toi-même avec
import pandas as pd
import chardet

# Détection de l'encodage
with open('chemin/vers/fichier.csv', 'rb') as f:
    result = chardet.detect(f.read(100000))
    encoding = result['encoding']

# Lecture du fichier avec l'encodage détecté
df = pd.read_csv('chemin/vers/fichier.csv', encoding=encoding)


# Ou tu peux aussi tout simplement changer l'encoding en utf-8 quand tu "save as" sur excel
