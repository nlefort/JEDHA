# %%
#exercice: collecter les données
#1.application web, données modifiable >> DICTIONNAIRE
#2.fichier excel à analyser je veux utiliser python pour analyser >> 1 LISTE POUR CHAQUE COLONNE
#3.collection de numéros uniques >> SET
