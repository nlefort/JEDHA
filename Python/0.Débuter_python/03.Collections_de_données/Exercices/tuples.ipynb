# %%
car_price=("ford mustang",50000)

# %%
#je peux accéder aux objets de mon tuple. Ici je veux accéder à l'item 1
car_price[1]
# Out:
# 50000

# %%
#mais je ne peux pas le modifier
car_price[1]=3000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 car_price[1]=3000
#
# TypeError: 'tuple' object does not support item assignment

# %%
#comment l'insérer dans notre dictionnaire ? en remplaçant mes {}, par ()
#rappel, les crochets après les variables [0] servent à aller cherche dans l'index crée
friends=input("what are the names of your friends (separate their names by a comma")
amounts=input("how much each of your friends spent (keep the same order as above and separate by a comma)")

list_of_friends=friends.split(",")
list_of_amounts=amounts.split(",")

friends=[
    (list_of_friends[0], list_of_amounts [0]),
    (list_of_friends[1], list_of_amounts [1])
]

# %%
print(friends)
# Out:
# [('lili', '20'), (' odile', ' 60')]
