# %%
#Exercice : vide et rien c'est pareil ?
nul=0
vide="None"
nul==vide

#vide n'est pas égal à 0
# Out:
# False

# %%
#projet des données, des données et encore des données
data=input("entrez votre donnée, nous vous dirons quel type c'est")
print(type(data)) #tous les types de données sont de classes "str"
# Out:
# <class 'str'>

# %%
#exercice : l'esthétisme ne tient qu'à un nombre
x=1/2
y=1
z=5**(1/2) #une racine carrée = puissance 1/2
nb=x*(y+z)
print(nb) #on obtient le nombre d'or
# Out:
# 1.618033988749895

# %%
#les daltons
bill=input("Quelle est ta taille, Bill?")
grat=input("Quelle est ta taille, Grat?")

print("Quelle est ta taille, Bill?" +bill)
print("Quelle est ta taille, Grat?"+grat)

bill>grat

bill=int(bill)
grat=int(grat)

bob=bill+10
emmet=grat+10

print(bob)
print(emmet)

bob!=emmet
print(bob!=emmet)
# Out:
# Quelle est ta taille, Bill?156
# Quelle est ta taille, Grat?123
# 166
# 133
# True

# %%
#Lucky Luke est perdu
a="o" in "bob"
print(a)

bb="b" in ("bob" and "bernard")
print(bb)

c= "a" in ("grat" or "emmet")
print(c)
# Out:
# True
# True
# True

# %%
#un peu de poésie

vers1="au bout de sa langue \n"
vers1=vers1.capitalize()
vers2="il cache des paysages \n"
vers2=vers2.capitalize()
vers3="l'étranger \n"
vers3=vers3.capitalize()

haiku=vers1+vers2+vers3
print(haiku)
# Out:
# Au bout de sa langue
# Il cache des paysages
# L'étranger

# %%
#exercice - y'à trop de chiffres
a=1/3
print("%2.2f" % a)
# Out:
# 0.33

# %%
#projet text mining

text="Chaque Homme sur terre a un trésor qui l'attend, lui dit son coeur. Nous, les coeurs, en parlons rarement, car les Hommes ne veulent plus trouver ces trésors. Nous n'en parlons qu'aux petits enfants. Ensuite, nous laissons la vie se charger de conduire chacun vers son destin. Malheureusement, peu d'Hommes suivent le chemin qui leur est tracé, et qui est le chemin de la Légende Personnelle et de la félicité. La plupart voient le monde comme quelque chose de menaçant et, pour cette raison même, le monde devient en effet une chose menaçante."
text=text.lower()

separation=text.split(",")

mots_positifs=separation[0]
mots_positifs.find("trésor")

mot_positif=mots_positifs[28:34]
print(mot_positif)
# Out:
# trésor

# %%
#exercice, avec des si on pourrait mettre paris en bouteille

question_1=input("combien de fois la france a gagné la coupe du monde?")

if question_1==2:
    print("Bravo !")
else:
    print("Dommage, essaie avec une aute question")

question_2=input("de quelle couleur est pickachu?")

if question_2=="jaune":
    print("BRAVO!")
else:
    print("Dommage, essaie avec une aute question")

question_3=input("de quelle couleur était le cheval blan d'henri IV?")
if question_3=="blanc":
    print("BRAVO!")
else:
    print("essaie quelque chode de plus facile pour toi")
# Out:
# Dommage, essaie avec une aute question
# BRAVO!
# essaie quelque chode de plus facile pour toi

# %%
#un quiz un peu plus compliqué

question_1=input("de quelle couleur sont les schtroumpfs?")

while question_1!="bleu":
    print("dommage, tu as encore des progrès à faire")
    question_1=input("de quelle couleur sont les schtroumpfs?")

print("bravo tu commences à comprendre !")
# Out:
# bravo tu commences à comprendre !

# %%
#un quizz vraiment mieux
nb_essais=3

question_1=input("combien de fois la france a gagné la coupe du monde?")

while question_1 != "2":
    if nb_essais ==0:
        print("dommage tu as perdu !")
        break
    else :
        nb_essais -= 1
        print("il te reste {} chnaces".format(nb_essais))
        question_1=input("combien de fois la france a gagné la coupe du monde?")
# Out:
# il te reste 2 chnaces
# il te reste 1 chnaces
# il te reste 0 chnaces
# dommage tu as perdu !

# %%
#voilà comment ça fonctionne
def sqrt(nombre): #ma fonction est racine carrée, elle renvoie à une variable nombre
    result=nombre**(1/2) #voici comment se calcule ma fonction
    print(result) #je veux afficher le résultat
sqrt(9) #la racine carré de mon nombre est ...
# Out:
# 3.0

# %%
#1er ou 2nd de classe
def repas(classe = "seconde_classe"): #ma fonction est repas, mon argument est classe, le paramètre de mon argument est "première classe ou seconde classe"
    if "seconde_classe" == "oui": #mon paramètre par défaut
        print("Vous pouvez vous rendre dans le wagon-bar")
    elif classe =="premiere_classe": #sinon, 
        print("votre repas vous sera servi à votre place")
    else:
        ("si vous n'êtes ni en première ni en 2eme classe, vous êtes peut-être un passager clandestin")

# %%
#exceptionnellement pour vous

def acheter_son_billet(): #ma fonction est acheter_son_billet, je n'applique pas d'argument spécifique

    try:
        nb_billets=int(input("combien de billets souhaitez-vous réserver?"))
        print(type(nb_billets))

        if nb_billets < 1:
            raise ValueError ("vous devez au moins réserver un ticket!")
        if nb_billets > 14 :
            raise ValueError ("vous pouvez bénéficier d'un tarif de groupe, veuillez nous contacter par téléphone")
    except:
        print("vous devez renseigner un nombre entier de billet au format numérique")


    else:
        prix_total_commande=nb_billets*25
        print("vous avez réservé {} billets. Le montant total de votre commande s'élève à {} €".format(nb_billets, prix_total_commande))

acheter_son_billet()
#cet exercice ne fonctionne pas
# Out:
# <class 'int'>
# vous devez renseigner un nombre entier de billet au format numérique

# %%
#combien rapport le livret A ??

def epargne():
