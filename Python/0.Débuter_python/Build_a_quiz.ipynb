# %% [markdown]
# # Build a quizz
#
# ---

# %% [markdown]
# Let's tackle our first project together. Find a partner and start coding a quiz together! Your program should:
#
# 1. Ask a question to a user via the console
# 2. Verify whether the answer is correct or not
# 3. If the answer is correct, you should print out: `Good job! This is the right answer`
#
# * Else, it should print out : `Too bad! that is not the correct answer`
#
# 4. Ask three questions following this model.

# %%
print("Bienvenue dans ce quizz ! \n ---------------- \n")



def quizz():
    question_1=input("Où vit le Père Noël?")

    if question_1 != "Laponie":
            print("Votre réponse :" + question_1)
            print("Dommage, ce n'est pas la bonne réponse")
            question_1=input("Où vit le Père Noël?")
    else:
            question_1=question_1.lower()
            print("Super ! c'est la bonne réponse :)")
            
    if question_1 !="Laponie":
        print("Votre réponse :" + question_1)
        print("Dommage, ce n'est pas la bonne réponse")
        question_1=input("Où vit le Père Noël?")
    else:
        question_1=question_1.lower()
        print("Super ! c'est la bonne réponse :)")

    if question_1 != "Laponie":
            print("Votre réponse :" + question_1)
            print("Dommage, ce n'est pas la bonne réponse")
            question_1=input("Où vit le Père Noël?")
    else:
        question_1=question_1.lower()
        print("Super ! c'est la bonne réponse :)")

quizz()
# Out:
# Bienvenue dans ce quizz !
#  ----------------
#
# Votre réponse :3
# Dommage, ce n'est pas la bonne réponse
# Votre réponse :6
# Dommage, ce n'est pas la bonne réponse
# Super ! c'est la bonne réponse :)

# %% [markdown]
# There's a problem with our quizz : if the user has not given the right answer, the program goes to next question. We would rather like to ask again the same question if the answer was wrong.
#
# 5. Using a `while` loop, make sure that the same question will be asked again when the answer was wrong
#
# 6. Rewrite your code such that this behaviour is applied to all questions.

# %%
def quizz():
    question_1=input("Où vit le Père Noël?")

    while question_1 != "Laponie":
        print("Mauvaise réponse, essaie encore!")
        question_1=input("Où vit le Père Noël?")
    
    print("Bravo !")

quizz()
# Out:
# Mauvaise réponse, essaie encore!
# Mauvaise réponse, essaie encore!
# Mauvaise réponse, essaie encore!
# Mauvaise réponse, essaie encore!
# Bravo !

# %% [markdown]
# Now, we would like to tackle a last problem : we want to allow only 3 wrong answers (among all questions).
#
# 7. Improve your code : if the user makes 3 wrong answers, the program should stop and print ("Too bad, you lost the game !")

# %%
print("Bienvenue dans ce quizz ! \nTu as 3 chances")

question_1=input("Où vit le Père Noël?")
nb_chances=3 #je crée une variable nb_chances

while question_1 != "Laponie".lower(): #tant que la réponse est fausse
        
    if nb_chances==0: #...et s'il te reste 0 chances
        print("tu as perdu!")
        break #tu arrêtes la boucle
            
    else: #sinon, si ta réponse est fausse et que tu n'es pas à 0, tu pers 1 chance
        nb_chances-=1
        print(f"Dommage, il te reste {nb_chances} chances")
        question_1=input("Où vit le Père Noël?")

if nb_chances>0:
        question_2=input("Le chêne est il un arbres?")
while question_2 != "oui": #tant que la réponse est fausse
            
        if nb_chances==0: #...et s'il te reste 0 chances
            print("tu as perdu!")
            break #tu arrêtes la boucle
            
        else: #sinon, si ta réponse est fausse et que tu n'es pas à 0, tu pers 1 chance
            nb_chances-=1
            print(f"Dommage, il te reste {nb_chances} chances")
            question_2=input("Le chêne est il un arbres?")

if nb_chances>0:
        question_3=input("Les mamouth ont il disparu?")
        while question_3 != "oui": #tant que la réponse est fausse
                
            if nb_chances==0: #...et s'il te reste 0 chances
                print("tu as perdu!")
                break #tu arrêtes la boucle
                
            else: #sinon, si ta réponse est fausse et que tu n'es pas à 0, tu pers 1 chance
                nb_chances-=1
                print(f"Dommage, il te reste {nb_chances} chances")
                question_3=input("Les mamouth ont il disparu?")
        if question_3 == "oui":
            print("bravo tu as gagné le jeu !")
# Out:
# Bienvenue dans ce quizz !
# Tu as 3 chances
# bravo tu as gagné le jeu !
