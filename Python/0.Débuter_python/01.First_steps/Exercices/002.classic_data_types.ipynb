# %%
#exercice: c'est pas le nombre qui compte
int=2001291
float=3.14
c=int+float
type(c)
# Out:
# float

# %%
#exercice: caractère de nombre
ecole=42
type(ecole)
#type = int

str=str(ecole)
type(str)
# Out:
# str

# %%
a=3
b=4

# dis-moi quel est le type de contenu dans la variable 'a'. indique moi le format de ma valeur

print("a is a type of {}".format(type(a)))
print("b is a type of {}".format(type(b)))
# Out:
# a is a type of <class 'int'>
# b is a type of <class 'int'>

# %%
c=a/b
print(c)
print("c is a type of {}".format(type(c)))
# Out:
# 0.75
# c is a type of <class 'float'>

# %%
#on peut assembler 2 chaînes de caractères avec "+"
first_name="Nadège"
last_name="Lefort"
first_name+last_name
# Out:
# 'NadègeLefort'

# %%
# je peux multiplier ma chaîne
first_name*4
# Out:
# 'NadègeNadègeNadègeNadège'

# %%
"""Je peux aller chercher dans ma chaîne un caractère avec la fonction index [].
le premier caractère =0 (donc N=0)"""
first_name[2]
# Out:
# 'd'

# %%
#on peut aligner les variables entre elles par une virgule

total_numbers_of_friends,total_amount_spent=input("how many firends traveled with you ?"),input('how much did you spend during your trip?')

print(total_numbers_of_friends)
print(total_amount_spent)
# Out:
# 3
# 3

# %%
#ceci est une variable chaîne de caractères
type(total_amount_spent)
# Out:
# str

# %%
#ceci est toujours une variable chaîne de caractère
total_amount_spent+total_numbers_of_friends
# Out:
# '33'

# %%
#je transforme ma chaîne de caractère en classe int()
total_amount_spent=int(total_amount_spent)
total_numbers_of_friends=int(total_numbers_of_friends)

print(type(total_amount_spent))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #je transforme ma chaîne de caractère en classe int()
# ----> 2 total_amount_spent=int(total_amount_spent)
#       3 total_numbers_of_friends=int(total_numbers_of_friends)
#       5 print(type(total_amount_spent))
#
# TypeError: 'int' object is not callable
