# %%
#Variables, un nombre chouette

pi=1.43
pi=3.14

# %%
#Opérations entre variables
a=10
print(a+15)
print(a-5)
print(a*2)
print(a/2)
print(a**2)
# Out:
# 25
# 5
# 20
# 5.0
# 100

# %%
b=32
print(a+b)
print(a/b)
print(a**b)
print(b//2) #reste du quotient
print(b%2) #dit si c'est un nombre pair ou non
# Out:
# 42
# 0.3125
# 100000000000000000000000000000000
# 16
# 0

# %%
c=a*b
print(c)
# Out:
# 320

# %%
#l'arbre au fruit magique
fruits=3*12
fruits_mangé=1
fruits_restants=fruits-fruits_mangé
fruits_restants
# Out:
# 35

# %%
#variables texte
chien="berger allemand"
chien="caniche"
print(chien)
# Out:
# caniche

# %%
#concaténer une variable avec une chaîne de caractères
merci='merci beaucoup '
prénom="Alec"

print(merci + prénom)
# Out:
# merci beaucoup Alec

# %%
#Compliment
prénom= input("quel est votre prénom ?")
print("Vous êtes rayonnant aujourd'hui " + prénom)
# Out:
# Vous êtes rayonnant aujourd'hui Aloïs
