# %%
a=10
b=5

# %%
if a ==b :
    print("a is equal to b")
elif a>b :
    print("a is greater than b")
else :
    print("a is neither equal nor greater than b")
# Out:
# a is greater than b

# %%
# le programme check d'abord si a == b, ce qui est faux. Puis, il va à la 2e condition, qui elle est vraie. C'est pourquoi il a écrit "a is greater than b" et il s'arrête là.

# %%
# si je change les valeurs
# et que j'éxécute à nouveau le programme
a=5
b=10

if a ==b :
    print("a is equal to b")
elif a>b :
    print("a is greater than b")
else :
    print("a is neither equal nor greater than b")
# Out:
# a is neither equal nor greater than b
