# %% [markdown]
# # Create a password
#
# ---

# %% [markdown]
# We would like to create a password for JEDHA
#
#     1. Using a WHILE loop, find a way to create a very simple authentication script

# %%
mdp=input("Quel est le mot de passe ")

if mdp == "BRAVO"
    print("Tu a le mot de passe!")
else:
    input("dommage!")
# Out:
# mauvaise réponse

# %%
mdp=input("Quel est le mot de passe ")

while mdp != "BRAVO":
    mdp=input("Quel est le mot de passe ")

print("tu es une championne !")
